# %% [markdown]
# Research:
# https://medium.com/analytics-vidhya/using-machine-learning-to-predict-flight-delays-e8a50b0bb64c
#
# Another possible data set to use instead
# https://www.kaggle.com/yuanyuwendymu/airline-delay-and-cancellation-data-2009-2018

# %% [markdown]
# ### Will the flight be delayed at the destination?

# %%
import pandas as pd

df = pd.read_csv('nyc-flights.csv',
                 parse_dates= {"date" : ["year","month","day"]},
                keep_date_col=False)

# %%
df.sort_values(by='date', inplace=True)

# %% [markdown]
# ### Modify and add new categorical variables

# %%
#https://stackoverflow.com/questions/32278728/convert-dataframe-date-row-to-a-weekend-not-weekend-value/32280195
# Adding a new weekday variable - 1 means weekday, 2 means weekend
df['weekday'] = (df['date'].dt.dayofweek < 5).astype(float)
df[['weekday']].value_counts()
# Out:
# weekday
# 1.0        24384
# 0.0         8351
# dtype: int64

# %%
df.head()
# Out:
#             date  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 23577 2013-01-01       855         -4      1143         -2      DL  N646DL
# 2903  2013-01-01      1529         -1      1733         -4      US  N738US
# 702   2013-01-01       753         -2      1056        -14      AA  N3HMAA
# 2951  2013-01-01      1701         -9      2026         11      AA  N3FUAA
# 14643 2013-01-01      1603         -2      1818         28      MQ  N730MQ
#
#        flight origin dest  air_time  distance  hour  minute  weekday
# 23577    1747    LGA  ATL       129       762     8      55      1.0
# 2903     1665    LGA  CLT       103       544    15      29      1.0
# 702      2267    LGA  MIA       157      1096     7      53      1.0
# 2951      695    JFK  AUS       247      1521    17       1      1.0
# 14643    4415    LGA  RDU        79       431    16       3      1.0

# %%
df.dtypes
# Out:
# date         datetime64[ns]
# dep_time              int64
# dep_delay             int64
# arr_time              int64
# arr_delay             int64
# carrier              object
# tailnum              object
# flight                int64
# origin               object
# dest                 object
# air_time              int64
# distance              int64
# hour                  int64
# minute                int64
# weekday             float64
# dtype: object

# %%
# hour 5 am-12 pm morning [5-12]
# 12-17 afternoon [12-5]
# 17 - 23 pm evening [5-11]
# 23 - 5 am redeye [11-5]
import math
import numpy as np
#https://www.dataquest.io/blog/tutorial-add-column-pandas-dataframe-based-on-if-else-condition/
    
df['dep_time_hour'] = ((df['dep_time']/100).astype('int'))

conditions = [
    (df['dep_time_hour'] >= 5) & (df['dep_time_hour'] < 12),
    (df['dep_time_hour'] >= 12) & (df['dep_time_hour'] < 17),
    (df['dep_time_hour'] >= 17) & (df['dep_time_hour'] < 23),
    (df['dep_time_hour'] >= 23) & (df['dep_time_hour'] < 5)
    ]

# create a list of the values we want to assign for each condition
values = [0,1,2,3]
#values = ['morning', 'afternoon', 'evening', 'red-eye']

# create a new column and use np.select to assign values to it using our lists as arguments
df['dep_time_category'] = np.select(conditions, values)

# display updated DataFrame
df.head()
# Out:
#             date  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 23577 2013-01-01       855         -4      1143         -2      DL  N646DL
# 2903  2013-01-01      1529         -1      1733         -4      US  N738US
# 702   2013-01-01       753         -2      1056        -14      AA  N3HMAA
# 2951  2013-01-01      1701         -9      2026         11      AA  N3FUAA
# 14643 2013-01-01      1603         -2      1818         28      MQ  N730MQ
#
#        flight origin dest  air_time  distance  hour  minute  weekday  \
# 23577    1747    LGA  ATL       129       762     8      55      1.0
# 2903     1665    LGA  CLT       103       544    15      29      1.0
# 702      2267    LGA  MIA       157      1096     7      53      1.0
# 2951      695    JFK  AUS       247      1521    17       1      1.0
# 14643    4415    LGA  RDU        79       431    16       3      1.0
#
#        dep_time_hour  dep_time_category
# 23577              8                  0
# 2903              15                  1
# 702                7                  0
# 2951              17                  2
# 14643             16                  1

# %%
# arrival time
import math
import numpy as np
#https://www.dataquest.io/blog/tutorial-add-column-pandas-dataframe-based-on-if-else-condition/
    
df['arr_time_hour'] = ((df['arr_time']/100).astype('int'))

conditions = [
    (df['arr_time_hour'] >= 5) & (df['arr_time_hour'] < 12),
    (df['arr_time_hour'] >= 12) & (df['arr_time_hour'] < 17),
    (df['arr_time_hour'] >= 17) & (df['arr_time_hour'] < 23),
    (df['arr_time_hour'] >= 23) & (df['arr_time_hour'] < 5)
    ]

# create a list of the values we want to assign for each condition
values = [0,1,2,3]
#values = ['morning', 'afternoon', 'evening', 'red-eye']

# create a new column and use np.select to assign values to it using our lists as arguments
df['arr_time_category'] = np.select(conditions, values)

# display updated DataFrame
df.head()
# Out:
#             date  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 23577 2013-01-01       855         -4      1143         -2      DL  N646DL
# 2903  2013-01-01      1529         -1      1733         -4      US  N738US
# 702   2013-01-01       753         -2      1056        -14      AA  N3HMAA
# 2951  2013-01-01      1701         -9      2026         11      AA  N3FUAA
# 14643 2013-01-01      1603         -2      1818         28      MQ  N730MQ
#
#        flight origin dest  air_time  distance  hour  minute  weekday  \
# 23577    1747    LGA  ATL       129       762     8      55      1.0
# 2903     1665    LGA  CLT       103       544    15      29      1.0
# 702      2267    LGA  MIA       157      1096     7      53      1.0
# 2951      695    JFK  AUS       247      1521    17       1      1.0
# 14643    4415    LGA  RDU        79       431    16       3      1.0
#
#        dep_time_hour  dep_time_category  arr_time_hour  arr_time_category
# 23577              8                  0             11                  0
# 2903              15                  1             17                  2
# 702                7                  0             10                  0
# 2951              17                  2             20                  2
# 14643             16                  1             18                  2

# %%
new_df = df.drop(columns=['tailnum', 'flight','hour','minute','dep_time_hour','arr_time_hour','dep_time','arr_time'])

# %%
new_df.head()
# Out:
#             date  dep_delay  arr_delay carrier origin dest  air_time  \
# 23577 2013-01-01         -4         -2      DL    LGA  ATL       129
# 2903  2013-01-01         -1         -4      US    LGA  CLT       103
# 702   2013-01-01         -2        -14      AA    LGA  MIA       157
# 2951  2013-01-01         -9         11      AA    JFK  AUS       247
# 14643 2013-01-01         -2         28      MQ    LGA  RDU        79
#
#        distance  weekday  dep_time_category  arr_time_category
# 23577       762      1.0                  0                  0
# 2903        544      1.0                  1                  2
# 702        1096      1.0                  0                  0
# 2951       1521      1.0                  2                  2
# 14643       431      1.0                  1                  2

# %%
# chart ideas
# count delays for each diff time category bar chart
# count delays for weekends vs weekdays bar chart

# %%
new_df['dep_delay'] = (new_df['dep_delay'] > 0).astype(int)

# %%
new_df.tail()
# Out:
#             date  dep_delay  arr_delay carrier origin dest  air_time  \
# 19776 2013-12-31          1          6      9E    JFK  DCA        54
# 3849  2013-12-31          0        -35      EV    LGA  ORF        51
# 5562  2013-12-31          1         45      B6    JFK  FLL       180
# 2742  2013-12-31          0        -12      DL    LGA  ATL       129
# 26857 2013-12-31          0         24      B6    JFK  FLL       181
#
#        distance  weekday  dep_time_category  arr_time_category
# 19776       213      1.0                  2                  2
# 3849        296      1.0                  1                  2
# 5562       1069      1.0                  0                  1
# 2742        762      1.0                  0                  0
# 26857      1069      1.0                  0                  1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,10))   
sns.heatmap(new_df.corr(), annot=True, vmin=-1, vmax=1, center= 0, ax=ax)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(new_df, hue='dep_time_category')

# %% [raw]
# try decision tree
# classify date as weekend or not

# %%
print(df['dep_time_category'].value_counts())
# Out:
# 0    13283
# 1     9922
# 2     9530
# Name: dep_time_category, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt

# variables to track the delays
morning = 0
afternoon = 0
evening = 0
redeye = 0


for index,row in df.iterrows():
    if(row['dep_time_category'] == 0 and row['dep_delay'] > 0):
        morning += 1
    elif(row['dep_time_category'] == 1 and row['dep_delay'] > 0):
        afternoon += 1
    elif(row['dep_time_category'] == 2 and row['dep_delay'] > 0):
        evening += 1
    elif(row['dep_time_category'] == 3 and row['dep_delay'] > 0):
        redeye += 1
        
xAxis = ["Morning", "Afternoon", "Evening", "RedEye"]
yAxis = [morning/13283, afternoon/9922, evening/9530, redeye]

plt.bar(xAxis,yAxis)
plt.title('Delays based on time of day')
plt.xlabel('Time of the day')
plt.ylabel('Ratio of Delays')
plt.show()

# %%
df['carrier'].value_counts()
# Out:
# UA    5770
# B6    5376
# EV    5142
# DL    4751
# AA    3188
# MQ    2507
# US    2015
# 9E    1696
# WN    1261
# VX     497
# FL     307
# F9      69
# AS      66
# YV      53
# HA      34
# OO       3
# Name: carrier, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt

# variables to track the delays
dl = 0
us = 0
aa = 0
mq = 0
vx = 0
ev = 0
wn = 0
b6 = 0
_9e = 0
ua = 0
fl = 0
f9 = 0
ha = 0
yv = 0
_as = 0
oo = 0

for index,row in df.iterrows():
    if(row['carrier'] == 'DL' and row['dep_delay'] > 0):
        dl += 1
    elif(row['carrier'] == 'US' and row['dep_delay'] > 0):
        us += 1
    elif(row['carrier'] == 'AA' and row['dep_delay'] > 0):
        aa += 1
    elif(row['carrier'] == 'MQ' and row['dep_delay'] > 0):
        mq += 1
    elif(row['carrier'] == 'VX' and row['dep_delay'] > 0):
        vx += 1
    elif(row['carrier'] == 'EV' and row['dep_delay'] > 0):
        ev += 1
    elif(row['carrier'] == 'WN' and row['dep_delay'] > 0):
        wn += 1
    elif(row['carrier'] == 'B6' and row['dep_delay'] > 0):
        b6 += 1
    elif(row['carrier'] == '9E' and row['dep_delay'] > 0):
        _9e += 1
    elif(row['carrier'] == 'UA' and row['dep_delay'] > 0):
        ua += 1    
    elif(row['carrier'] == 'FL' and row['dep_delay'] > 0):
        fl += 1
    elif(row['carrier'] == 'F9' and row['dep_delay'] > 0):
        f9 += 1
    elif(row['carrier'] == 'HA' and row['dep_delay'] > 0):
        ha += 1
    elif(row['carrier'] == 'YV' and row['dep_delay'] > 0):
        yv += 1
    elif(row['carrier'] == 'AS' and row['dep_delay'] > 0):
        _as += 1
    elif(row['carrier'] == 'OO' and row['dep_delay'] > 0):
        oo += 1
        
xAxis = ["DL", "US", "AA", "MQ","VX", "EV", "WN", "B6","9E", "UA", "FL", "F9","HA", "YV", "AS", "OO"]
yAxis = [dl/4751, us/2015, aa/3188, mq/2507, vx/497, ev/5142, wn/1261, b6/5376, _9e/1696, ua/5770, fl/307, f9/69, ha/34, yv/53, _as/66, oo/3]

plt.bar(xAxis,yAxis)
plt.title('Delays based on carrier')
plt.xlabel('Carrier')
plt.ylabel('Ratio of delays')
plt.show()

# %%
df['weekday'].value_counts()
# Out:
# 1.0    24384
# 0.0     8351
# Name: weekday, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt

weekday = 0
weekend = 0

for index,row in df.iterrows():
    if(row['weekday'] == 1.0 and row['dep_delay'] > 0):
        weekday += 1
    elif(row['weekday'] == 0.0 and row['dep_delay'] > 0):
        weekend += 1
        
xAxis = ["Weekday", "Weekend"]
yAxis = [weekday/24384, weekend/8351]

plt.bar(xAxis,yAxis)
plt.title('Delays on weekdays and weekends')
plt.ylabel('Number of delays')
plt.show()

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %% [markdown]
# principal component analysis
# subtract arrival time from departure time

# %%
X = new_df[['air_time','weekday','dep_time_category']]
y = new_df[['dep_delay']]
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
clf = DecisionTreeClassifier(criterion="entropy", max_depth=3)
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6443335709194583

# %%
from sklearn.tree import export_graphviz
from six import StringIO
#from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = X.columns,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes.png')
Image(graph.create_png())

# %% [markdown]
# https://www.datacamp.com/community/tutorials/decision-tree-classification-python

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
