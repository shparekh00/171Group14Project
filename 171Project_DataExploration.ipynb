# %% [markdown]
# Research:
# https://medium.com/analytics-vidhya/using-machine-learning-to-predict-flight-delays-e8a50b0bb64c
#
# Another possible data set to use instead
# https://www.kaggle.com/yuanyuwendymu/airline-delay-and-cancellation-data-2009-2018

# %% [markdown]
# ### Will the flight be delayed at the destination?

# %%
import pandas as pd

df = pd.read_csv('nyc-flights.csv')

# %%
df.head(10)
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      6   30       940         15      1216         -4      VX  N626VA
# 1  2013      5    7      1657         -3      2104         10      DL  N3760C
# 2  2013     12    8       859         -1      1238         11      DL  N712TW
# 3  2013      5   14      1841         -4      2122        -34      DL  N914DL
# 4  2013      7   21      1102         -3      1230         -8      9E  N823AY
# 5  2013      1    1      1817         -3      2008          3      AA  N3AXAA
# 6  2013     12    9      1259         14      1617         22      WN  N218WN
# 7  2013      8   13      1920         85      2032         71      B6  N284JB
# 8  2013      9   26       725        -10      1027         -8      AA  N3FSAA
# 9  2013      4   30      1323         62      1549         60      EV  N12163
#
#    flight origin dest  air_time  distance  hour  minute
# 0     407    JFK  LAX       313      2475     9      40
# 1     329    JFK  SJU       216      1598    16      57
# 2     422    JFK  LAX       376      2475     8      59
# 3    2391    JFK  TPA       135      1005    18      41
# 4    3652    LGA  ORF        50       296    11       2
# 5     353    LGA  ORD       138       733    18      17
# 6    1428    EWR  HOU       240      1411    12      59
# 7    1407    JFK  IAD        48       228    19      20
# 8    2279    LGA  MIA       148      1096     7      25
# 9    4162    EWR  JAX       110       820    13      23

# %%
new_df = df.drop(columns=['carrier','tailnum', 'flight', 'origin','year','month','day'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,10))   
sns.heatmap(new_df.corr(), annot=True, vmin=-1, vmax=1, center= 0, ax=ax)
# Out:
# <AxesSubplot:>
